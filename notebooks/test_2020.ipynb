# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import plotly.express as px
import plotly.graph_objects as go
import holidays
import seaborn as sns

# %%
energy = pd.read_csv("D:/GitHub_Web/energy/src/data/processed/combined_data.csv")
energy["SETTLEMENTDATE"] = pd.to_datetime(energy["SETTLEMENTDATE"])
energy
# Out:
#             SETTLEMENTDATE  TOTALDEMAND    RRP Weekday  Holiday
# 0      2018-01-01 00:30:00      4251.18  92.46  Monday     True
# 1      2018-01-01 01:00:00      4092.53  87.62  Monday     True
# 2      2018-01-01 01:30:00      3958.95  73.08  Monday     True
# 3      2018-01-01 02:00:00      3785.27  70.18  Monday     True
# 4      2018-01-01 02:30:00      3673.72  67.43  Monday     True
# ...                    ...          ...    ...     ...      ...
# 293803 2023-12-31 23:40:00      4070.49  51.94  Sunday    False
# 293804 2023-12-31 23:45:00      4035.14  52.23  Sunday    False
# 293805 2023-12-31 23:50:00      4039.52  51.83  Sunday    False
# 293806 2023-12-31 23:55:00      4036.91  51.43  Sunday    False
# 293807 2024-01-01 00:00:00      4024.55  51.43  Monday     True
#
# [293808 rows x 5 columns]

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293808 entries, 0 to 293807
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SETTLEMENTDATE  293808 non-null  datetime64[ns]
#  1   TOTALDEMAND     293808 non-null  float64
#  2   RRP             293808 non-null  float64
#  3   Weekday         293808 non-null  object
#  4   Holiday         293808 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(2), object(1)
# memory usage: 9.2+ MB

# %%
energy_2020 = energy[energy["SETTLEMENTDATE"].dt.year == 2020]

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=energy_2020.SETTLEMENTDATE, y=energy_2020.TOTALDEMAND, mode='lines+markers', name='Demand (MW)'))
fig.add_trace(go.Scatter(x=energy_2020.SETTLEMENTDATE, y=energy_2020.RRP, mode='lines+markers', name='Price ($/MWh)'))

fig.update_layout(title='Energy Demand and Price in Australia - 2020',
                    width=1100, height=500,
                     xaxis_title='Time',
                     yaxis_title='Value')

fig.show()

# %%
energy_2020.loc[:, "Hour"] = energy_2020["SETTLEMENTDATE"].dt.hour
energy_2020.loc[:, "Minute"] = energy_2020["SETTLEMENTDATE"].dt.minute
energy_2020.loc[:, "Time"] = energy_2020["Hour"] + energy_2020["Minute"] / 60
energy_2020.loc[:, "Day"] = energy_2020["SETTLEMENTDATE"].dt.day
energy_2020.loc[:, "Month"] = energy_2020["SETTLEMENTDATE"].dt.month
energy_2020
# Out:
#            SETTLEMENTDATE  TOTALDEMAND    RRP    Weekday  Holiday  Hour  \
# 35039 2020-01-01 00:00:00      4372.27  85.23  Wednesday     True     0
# 35040 2020-01-01 00:30:00      4185.32  64.76  Wednesday     True     0
# 35041 2020-01-01 01:00:00      4057.68  63.36  Wednesday     True     1
# 35042 2020-01-01 01:30:00      3954.85  65.21  Wednesday     True     1
# 35043 2020-01-01 02:00:00      3792.25  64.45  Wednesday     True     2
# ...                   ...          ...    ...        ...      ...   ...
# 52602 2020-12-31 21:30:00      4103.51  35.05   Thursday    False    21
# 52603 2020-12-31 22:00:00      4034.28  35.49   Thursday    False    22
# 52604 2020-12-31 22:30:00      4067.00  48.25   Thursday    False    22
# 52605 2020-12-31 23:00:00      4115.25  38.66   Thursday    False    23
# 52606 2020-12-31 23:30:00      4363.19  50.15   Thursday    False    23
#
#        Minute  Time  Day  Month
# 35039       0   0.0    1      1
# 35040      30   0.5    1      1
# 35041       0   1.0    1      1
# 35042      30   1.5    1      1
# 35043       0   2.0    1      1
# ...       ...   ...  ...    ...
# 52602      30  21.5   31     12
# 52603       0  22.0   31     12
# 52604      30  22.5   31     12
# 52605       0  23.0   31     12
# 52606      30  23.5   31     12
#
# [17568 rows x 10 columns]

# %% [markdown]
# # Time vs Weekday Heatmap

# %%
week = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
tem = pd.crosstab(energy_2020.Time, energy_2020.Weekday, values=energy_2020.TOTALDEMAND, aggfunc='sum')
tem = tem.reindex(columns=week)

plt.figure(figsize=(8, 13))
sns.heatmap(tem, 
    annot=True, 
    fmt=".1f",
    linewidths=0.5,
    linecolor='white',
    cmap="coolwarm"
)
plt.xticks(rotation=0)
plt.title("Total Demand Heatmap by Time and Weekday for 2020")
plt.xlabel("Weekday")
plt.ylabel("Time")
plt.tight_layout()
plt.show()

# %% [markdown]
# - Lowest demand are from 2AM to 5AM, being the time where most people go to sleep.
# - Highest demand are from 5PM to 8PM, being the sunset hours and the lights are coming on.
# - Sat and Sun has the lowest demand in the week, being the weekend where offices are closed or operate at reduced capacity.
# - Thurs has the highest demand in the week, Mon next, and possibly Weds.

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(tem.T, 
    linewidths=0.5,
    linecolor='white',
    square=True,
    cbar_kws={"shrink": 0.2}
)
plt.xticks(rotation=45)
plt.title("Total Demand Heatmap by Time and Weekday for 2020")
plt.xlabel("Weekday")
plt.ylabel("Time")
plt.tight_layout()
plt.show()

# %% [markdown]
# - The dark patch is all over 2 till 5, with Sun and Mon being the darkest at those hours.
# - Thurs is the shiniest from 6 till 7.

# %% [markdown]
# # Day vs Month Heatmap

# %%
plt.figure(figsize=(13, 13))
sns.heatmap(pd.crosstab(energy_2020.Day, energy_2020.Month, values=energy_2020.TOTALDEMAND, aggfunc='sum'), 
    annot=True, 
    fmt=".1f",
    linewidths=0.5,
    linecolor='white',
    cmap="coolwarm"
)

ax = plt.gca()
holiday_data = energy_2020[energy_2020.Holiday == True]
for _, row in holiday_data.iterrows():
    rect = patches.Rectangle((row.Month-1, row.Day-1), 1, 1, 
                           fill=False, 
                           edgecolor='red',                                                                                                             
                           linewidth=2,
                           linestyle='-')
    ax.add_patch(rect)

plt.title("Total Demand Heatmap by Day and Month for 2020")
plt.xlabel("Month")
plt.ylabel("Day")
plt.tight_layout()
plt.show()

# %% [markdown]
# - All holidays are under the median of demand, some holidays are even among the lowest. This could be due to being the day where people hanging out with their friends and family and not occupiying in the house, bringing the electricity needs down.

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(pd.crosstab(energy_2020.Day, energy_2020.Month, values=energy_2020.TOTALDEMAND, aggfunc='sum').T, 
    linewidths=0.5,
    linecolor='white',
    square=True,
    cbar_kws={"shrink": 0.2},
    cmap="coolwarm"
)

plt.title("Total Demand Heatmap by Day and Month for 2020")
plt.ylabel("Month")
plt.xlabel("Day")
plt.tight_layout()
plt.show()

# %% [markdown]
# - High demand on weekday from around July 14th to the end of August. This period is mid-winter in Australia, leading to increased energy usage for heating.
# - Low demand on weekend from October 13th onward. October marks mid-spring, with milder temperatures reducing the need for heating or cooling.
# - An influx of demand from January 17th to 29th. This is due to heatwave, especially on 19th with 41 degrees C, 28th - 38 degrees C, and 29th - 32 degrees C. Extreme temperatures during this period have placed additional stress on the grid as residential, commercial, and industrial sectors rely heavily on cooling.
# - Some of the highest demand days (colored by red patches) are highly related to the heatwave as peak summer period is around those time.

# %%
fig,ax = plt.subplots(2,2,figsize=(15,15))

sns.boxenplot(x="Month", y="TOTALDEMAND", data=energy_2020, ax=ax[0,0])
ax[0,0].set_title("Total Demand by Month for 2020")

sns.boxenplot(x="Weekday", y="TOTALDEMAND", data=energy_2020, ax=ax[0,1], order=week)
ax[0,1].set_title("Total Demand by Weekday for 2020")

sns.boxenplot(x="Holiday", y="TOTALDEMAND", data=energy_2020, ax=ax[1,0])
ax[1,0].set_title("Total Demand by Holiday for 2020")

sns.boxenplot(x="Hour", y="TOTALDEMAND", data=energy_2020, ax=ax[1,1])
ax[1,1].set_title("Total Demand by Hour for 2020")
# Out:
# Text(0.5, 1.0, 'Total Demand by Hour for 2020')
